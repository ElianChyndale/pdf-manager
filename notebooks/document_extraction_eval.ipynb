# %% [markdown]
# # Document Extraction Evaluation
#
# Compare raw text extraction, OCR-only extraction, fixed-size chunking, and layout-aware extraction.

# %%
methods = ["raw_text", "ocr_only", "fixed_chunking", "layout_aware"]
metrics = ["character_error_rate", "word_error_rate", "table_accuracy", "section_accuracy", "retrieval_recall_at_k", "citation_accuracy", "latency_ms"]
results = {method: {metric: None for metric in metrics} for method in methods}
results
