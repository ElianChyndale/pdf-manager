# %% [markdown]
# # Chunking Evaluation
#
# Evaluate fixed-size chunks against layout-aware metadata chunks for retrieval and citation accuracy.

# %%
chunkers = ["fixed_size", "heading_based", "layout_aware"]
metrics = ["retrieval_recall_at_3", "retrieval_recall_at_5", "citation_accuracy"]
results = {chunker: {metric: None for metric in metrics} for chunker in chunkers}
results
